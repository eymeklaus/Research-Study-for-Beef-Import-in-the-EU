# %% [markdown]
# # Project Data Wrangling and Retrieval

# %% [markdown]
# # 1. Accesing APIs

# %%
# !pip install requests

# %%
import requests

# %%
url = "https://ec.europa.eu/agrifood/api/beef/prices?"

# %%
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en" class="no-js">\r\n<head>\r\n\t<title>Agri-food data portal | Agricultural markets</title>\r\n\t<meta name="agrititle" content="Agri-food data portal | Agricultural markets" />\r\n\t<meta name="description" content="Market data on national and European agriculture provided by the European Commission\'s agricultural and rural development department. Browse visualisations about imports, exports, prices, production and aid schemes.">\r\n\t<meta name="keywords" content="market data, national agriculture, European agriculture, European Commission, agriculture, rural development , exports, imports, prices, sector, market, aid scheme, beef, Pigmeat, Eggs and poultry, Sheep and goat meat, Milk and dairy products, Fruit and vegetables, Cereals, Rice, Oilseeds and protein crops, Sugar, Olive oil and table olives, Wine">\r\n\t<meta name="author" content="European Commission - Directorate-General for Agriculture and Rural Development">\r\n\t<meta name="viewpor
# ...

# %%
response.headers
# Out:
# {'Date': 'Fri, 20 Feb 2026 08:52:15 GMT', 'Content-Type': 'text/html;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'X-Qlik-Session=c798bcfe-b3f6-4a2e-a829-5ab09c48048b; Path=/; HttpOnly; SameSite=Strict; Secure', 'Cache-Control': 'private, must-revalidate, max-age=0', 'Content-Encoding': 'gzip', 'Expires': 'Mon, 01 Jan 0001 00:00:00 GMT', 'Last-Modified': 'Tue, 03 Feb 2026 12:37:32 GMT', 'Accept-Ranges': 'bytes', 'ETag': '639057190528705911', 'Server': 'Microsoft-HTTPAPI/2.0', 'X-UA-Compatible': 'IE=edge', 'Access-Control-Allow-Origin': 'https://agridata.ec.europa.eu', 'X-FRAME-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=31536000;includeSubDomains;Preload'}

# %%
info = response.json()

# %%
type(info)
# Out:
# list

# %%
response.json()
# Out:
# [{'memberStateCode': 'AT',
#   'memberStateName': 'Austria',
#   'beginDate': '09/02/2026',
#   'endDate': '15/02/2026',
#   'price': '€503.03',
#   'unit': '€/100Kg',
#   'weekNumber': 7,
#   'category': 'Young cattle',
#   'productCode': 'ZO2'},
#  {'memberStateCode': 'AT',
#   'memberStateName': 'Austria',
#   'beginDate': '09/02/2026',
#   'endDate': '15/02/2026',
#   'price': '€719.55',
#   'unit': '€/100Kg',
#   'weekNumber': 7,
#   'category': 'Heifers',
#   'productCode': 'EU2'},
#  {'memberStateCode': 'AT',
#   'memberStateName': 'Austria',
#   'beginDate': '09/02/2026',
#   'endDate': '15/02/2026',
#   'price': '€541.22',
#   'unit': '€/100Kg',
#   'weekNumber': 7,
#   'category': 'Cows',
#   'productCode': 'DP3'},
#  {'memberStateCode': 'AT',
#   'memberStateName': 'Austria',
#   'beginDate': '09/02/2026',
#   'endDate': '15/02/2026',
#   'price': '€800.77',
#   'unit': '€/100Kg',
#   'weekNumber': 7,
#   'category': 'Young cattle',
#   'productCode': 'ZU3'},
# ...

# %%
import pandas as pd
pd.DataFrame(info)
# Out:
#        memberStateCode memberStateName   beginDate     endDate    price  \
# 0                   AT         Austria  09/02/2026  15/02/2026  €503.03
# 1                   AT         Austria  09/02/2026  15/02/2026  €719.55
# 2                   AT         Austria  09/02/2026  15/02/2026  €541.22
# 3                   AT         Austria  09/02/2026  15/02/2026  €800.77
# 4                   AT         Austria  09/02/2026  15/02/2026  €719.85
# ...                ...             ...         ...         ...      ...
# 887499              ES           Spain  31/12/1990  06/01/1991   €96.29
# 887500              ES           Spain  31/12/1990  06/01/1991  €338.93
# 887501              ES           Spain  31/12/1990  06/01/1991  €307.97
# 887502              ES           Spain  31/12/1990  06/01/1991  €150.85
# 887503              ES           Spain  31/12/1990  06/01/1991  €330.80
#
#            unit  weekNumber      category productCode
# ...

# %%
# code to save dataframe in folder
import pandas as pd

df = pd.DataFrame(info)

print(type(df))   # should show DataFrame

df.to_csv(r"C:\Users\eymem\Documents\GitHub\Project-Data-Wrangling-and-Retrieval\Prices-Beef-EU-European-Commision.csv",index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
